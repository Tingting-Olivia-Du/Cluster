# %%
import torch

if torch.cuda.is_available():
    print("✅ GPU 可用！")
    print("GPU 名称:", torch.cuda.get_device_name(0))
    print("GPU 总显存: {:.2f} GB".format(torch.cuda.get_device_properties(0).total_memory / 1024 / 1024 / 1024))
else:
    print("❌ 没检测到 GPU！")
