# %%
#stat_with_gaussian
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Imports
import json
from tqdm import tqdm

# %%
start_index = 651
end_index = 655
range_tag = f"{start_index}-{end_index}"
BASE_PATH = "/content/drive/MyDrive/Cluster-proj"
INFERENCE_PATH = os.path.join(BASE_PATH, f"output/llm_steps/deepseek7b-math-{range_tag}.json")

# %%
# Load JSON data
with open(LOGITS_PATH, 'r') as f:
    logits_data = json.load(f)

with open(STEPS_PATH, 'r') as f:
    steps_data = json.load(f)
